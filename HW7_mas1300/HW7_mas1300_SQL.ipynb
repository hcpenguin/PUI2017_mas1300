# %%
#https://serv.cusp.nyu.edu/~hvo/files/SQL_Lab_Keys.pdf
#https://serv.cusp.nyu.edu/~hvo/files/SQL_Lab.pdf

#http://python-future.org/compatible_idioms.html
# helped by Baoling


SQL_SOURCE = 'https://mariums.carto.com/api/v2/sql?q='

try:
    import urllib2
    from urllib2 import HTTPError
    from urllib2 import urlopen
    from urllib import urlencode
    from StringIO import StringIO as io

except ImportError:
    import urllib
    from urllib.error import HTTPError
    from urllib.request import urlopen, Request
    from urllib.parse import urlencode
    from io import BytesIO as io


import ast
import pandas as pd

def queryCartoDB(query, format='CSV', source=SQL_SOURCE):
    '''queries carto datasets from a given carto account
    Arguments: 
    query - string: a valid sql query string
    format - outlut format  OPTIONAL (default CSV)
    source - a valid sql api endpoint OPTIONAL (default carto fb55 account)
    Returns:
    the return of the sql query AS A STRING
    NOTES:
    designed for the carto API, tested only with CSV return format'''
    
    data = urlencode({'format':format, 'q':query}).encode('utf-8')
    try:
        response = urlopen(source, data)
    except HTTPError as e:
        raise ValueError('\n'.join(ast.literal_eval(e.readline())['error']))
    except Exception:
        raise
    return response.read()

# %%
test = '''
SELECT *
FROM citibike
'''

# %%
pd.read_csv(io(queryCartoDB(test)), sep=',')
# Out:
#        cartodb_id  the_geom  the_geom_webmercator  gender  birth_year  bikeid  \
# 0            5960       NaN                   NaN       1      1965.0   19217
# 1            9806       NaN                   NaN       1      1971.0   17575
# 2           13113       NaN                   NaN       1      1973.0   20313
# 3               1       NaN                   NaN       2      1978.0   17131
# 4               2       NaN                   NaN       1      1993.0   21289
# 5               3       NaN                   NaN       2      1969.0   18903
# 6               4       NaN                   NaN       2      1985.0   21044
# 7               5       NaN                   NaN       1      1957.0   19868
# 8               6       NaN                   NaN       1      1979.0   15854
# 9               7       NaN                   NaN       1      1983.0   15173
# 10              8       NaN                   NaN       1      1955.0   17862
# ...

# %%
'''Sort data by start_station_id, tripduration''' 
#https://www.tutorialspoint.com/sql/sql-sorting-results.htm

sort1 = '''
SELECT *
FROM citibike
   ORDER BY start_station_id, tripduration;
'''

# %%
pd.read_csv(io(queryCartoDB(sort1)), sep=',')
# Out:
#        cartodb_id  the_geom  the_geom_webmercator  gender  birth_year  bikeid  \
# 0            8998       NaN                   NaN       2      1980.0   19039
# 1           40759       NaN                   NaN       2      1959.0   18131
# 2           40757       NaN                   NaN       1      1995.0   19729
# 3           21948       NaN                   NaN       1      1970.0   16879
# 4           43099       NaN                   NaN       1      1983.0   15277
# 5           32566       NaN                   NaN       1      1971.0   18492
# 6           15971       NaN                   NaN       1      1961.0   19216
# 7           41355       NaN                   NaN       1      1974.0   21588
# 8           42074       NaN                   NaN       1      1978.0   19124
# 9            2282       NaN                   NaN       1      1974.0   18174
# 10          44674       NaN                   NaN       1      1983.0   18198
# ...

# %%
'''Only checking trips with duration <= 3 hours [aka 10800 seconds]'''
#http://www.peachpit.com/articles/article.aspx?p=1276352&seqNum=8

sort2 = '''
SELECT *
FROM citibike
   WHERE tripduration <= 10800
   ORDER BY start_station_id, tripduration;
   
'''

# %%
pd.read_csv(io(queryCartoDB(sort2)), sep=',')
# Out:
#        cartodb_id  the_geom  the_geom_webmercator  gender  birth_year  bikeid  \
# 0            8998       NaN                   NaN       2      1980.0   19039
# 1           40759       NaN                   NaN       2      1959.0   18131
# 2           40757       NaN                   NaN       1      1995.0   19729
# 3           21948       NaN                   NaN       1      1970.0   16879
# 4           43099       NaN                   NaN       1      1983.0   15277
# 5           32566       NaN                   NaN       1      1971.0   18492
# 6           15971       NaN                   NaN       1      1961.0   19216
# 7           41355       NaN                   NaN       1      1974.0   21588
# 8           42074       NaN                   NaN       1      1978.0   19124
# 9            2282       NaN                   NaN       1      1974.0   18174
# 10          44674       NaN                   NaN       1      1983.0   18198
# ...

# %%
'''Only show the top/last 10 records (aka head and tail in SQL) '''
#https://blog.sqlauthority.com/2008/03/02/sql-server-how-to-retrieve-top-and-bottom-rows-together-using-t-sql/

sort3 = '''

SELECT * FROM citibike
ORDER BY bikeid
LIMIT 10 '''

# %%
pd.read_csv(io(queryCartoDB(sort3)), sep=',')
# Out:
#    cartodb_id  the_geom  the_geom_webmercator  gender  birth_year  bikeid  \
# 0       21692       NaN                   NaN       2        1976   14530
# 1       23252       NaN                   NaN       1        1982   14530
# 2       18500       NaN                   NaN       1        1969   14530
# 3       19155       NaN                   NaN       1        1972   14530
# 4       12277       NaN                   NaN       2        1982   14530
# 5       11561       NaN                   NaN       1        1975   14530
# 6       18123       NaN                   NaN       1        1972   14530
# 7       12238       NaN                   NaN       1        1964   14530
# 8       25887       NaN                   NaN       2        1983   14530
# 9       25120       NaN                   NaN       1        1967   14530
#
#    end_station_id  start_station_id  tripduration    usertype  \
# 0             410               438           362  Subscriber
# ...

# %%
'''last10'''

sort4 = '''
SELECT * FROM citibike
ORDER BY bikeid DESC
LIMIT 10;


'''

# %%
pd.read_csv(io(queryCartoDB(sort4)), sep=',')
# Out:
#    cartodb_id  the_geom  the_geom_webmercator  gender  birth_year  bikeid  \
# 0       31043       NaN                   NaN       1      1961.0   21699
# 1       31323       NaN                   NaN       1      1986.0   21699
# 2       31751       NaN                   NaN       1      1978.0   21698
# 3       44925       NaN                   NaN       1      1990.0   21697
# 4       41070       NaN                   NaN       2      1989.0   21697
# 5       44041       NaN                   NaN       2      1952.0   21697
# 6        4571       NaN                   NaN       2      1990.0   21690
# 7        2690       NaN                   NaN       0         NaN   21690
# 8        9257       NaN                   NaN       1      1981.0   21690
# 9        6755       NaN                   NaN       1      1975.0   21690
#
#    end_station_id  start_station_id  tripduration    usertype  \
# 0             359               490           586  Subscriber
# ...

# %%
'''• List all unique start_station_id values '''
#http://www.dofactory.com/sql/select-distinct

sort5 = '''
SELECT DISTINCT start_station_id
FROM citibike;


'''

# %%
pd.read_csv(io(queryCartoDB(sort5)), sep=',')
# Out:
#      start_station_id  Unnamed: 1
# 0                 195         NaN
# 1                 251         NaN
# 2                 285         NaN
# 3                 120         NaN
# 4                 483         NaN
# 5                 264         NaN
# 6                 497         NaN
# 7                 305         NaN
# 8                 318         NaN
# 9                 312         NaN
# 10                496         NaN
# 11                455         NaN
# 12                470         NaN
# 13                276         NaN
# 14               2008         NaN
# 15                313         NaN
# 16                262         NaN
# 17                362         NaN
# 18                151         NaN
# 19                384         NaN
# 20                119         NaN
# 21                399         NaN
# 22                356         NaN
# 23                270         NaN
# 24                437         NaN
# 25                514         NaN
# ...

# %%
'''Count the number of trips (aka wc -l in SQL)'''
'''Find the average/min/max trip duration'''

test1 = '''SELECT COUNT(tripduration)
  FROM citibike'''

test2 = '''SELECT SUM(tripduration)
  FROM citibike'''

test3 = '''SELECT AVG(tripduration)
  FROM citibike'''

test4 = '''SELECT MIN(tripduration)
  FROM citibike'''

test5 = '''SELECT MAX(tripduration)
  FROM citibike'''

# %%
print pd.read_csv(io(queryCartoDB(test1)), sep=',')
print pd.read_csv(io(queryCartoDB(test2)), sep=',')
print pd.read_csv(io(queryCartoDB(test3)), sep=',')
print pd.read_csv(io(queryCartoDB(test4)), sep=',')
print pd.read_csv(io(queryCartoDB(test5)), sep=',')
# Out:
#    count  Unnamed: 1
# 0  46200         NaN
#         sum  Unnamed: 1
# 0  31225001         NaN
#           avg  Unnamed: 1
# 0  675.865823         NaN
#    min  Unnamed: 1
# 0   60         NaN
#      max  Unnamed: 1
# 0  43016         NaN

# %%
'''• Selecting trips started on Feb-02-2015 only '''
#helped by baoling

time1= '''select * from citibike
where starttime 
between '02/02/2015 00:00:00.00' and '02/02/2015 23:59:59.999'
'''

# %%
pd.read_csv(io(queryCartoDB(time1)), sep=',')
# Out:
#       cartodb_id  the_geom  the_geom_webmercator  gender  birth_year  bikeid  \
# 0           6442       NaN                   NaN       1      1992.0   20684
# 1           6443       NaN                   NaN       2      1964.0   16094
# 2           6444       NaN                   NaN       1      1974.0   17362
# 3           6445       NaN                   NaN       2      1992.0   15475
# 4           6446       NaN                   NaN       1      1968.0   16272
# 5           6447       NaN                   NaN       1      1979.0   16370
# 6           6448       NaN                   NaN       1      1963.0   19437
# 7           6449       NaN                   NaN       1      1982.0   21211
# 8           6450       NaN                   NaN       2      1978.0   21417
# 9           6451       NaN                   NaN       1      1956.0   15722
# 10          6452       NaN                   NaN       1      1962.0   18972
# ...

# %%
'''Selecting trips started on the weekends '''
#helped by shreya
#https://blog.sqlauthority.com/2007/07/23/sql-server-udf-get-the-day-of-the-week-function/

time2 = '''select * from citibike
where extract(DOW from starttime) IN (0,6)'''

# %%
pd.read_csv(io(queryCartoDB(time2)), sep=',')
# Out:
#        cartodb_id  the_geom  the_geom_webmercator  gender  birth_year  bikeid  \
# 0            5960       NaN                   NaN       1      1965.0   19217
# 1               1       NaN                   NaN       2      1978.0   17131
# 2               2       NaN                   NaN       1      1993.0   21289
# 3               3       NaN                   NaN       2      1969.0   18903
# 4               4       NaN                   NaN       2      1985.0   21044
# 5               5       NaN                   NaN       1      1957.0   19868
# 6               6       NaN                   NaN       1      1979.0   15854
# 7               7       NaN                   NaN       1      1983.0   15173
# 8               8       NaN                   NaN       1      1955.0   17862
# 9               9       NaN                   NaN       2      1985.0   21183
# 10             10       NaN                   NaN       1      1982.0   14843
# ...

# %%
'''Selecting trips started on the weekdays '''

time3 = '''select * from citibike
where extract(DOW from starttime) NOT IN (1,6)'''

# %%
pd.read_csv(io(queryCartoDB(time3)), sep=',')
# Out:
#        cartodb_id  the_geom  the_geom_webmercator  gender  birth_year  bikeid  \
# 0            5960       NaN                   NaN       1      1965.0   19217
# 1            9806       NaN                   NaN       1      1971.0   17575
# 2           13113       NaN                   NaN       1      1973.0   20313
# 3               1       NaN                   NaN       2      1978.0   17131
# 4               2       NaN                   NaN       1      1993.0   21289
# 5               3       NaN                   NaN       2      1969.0   18903
# 6               4       NaN                   NaN       2      1985.0   21044
# 7               5       NaN                   NaN       1      1957.0   19868
# 8               6       NaN                   NaN       1      1979.0   15854
# 9               7       NaN                   NaN       1      1983.0   15173
# 10              8       NaN                   NaN       1      1955.0   17862
# ...

# %%
'''Showing the list of start station locations
- Using GROUP BY '''

group1= '''select start_station_latitude, start_station_longitude from citibike

group by start_station_latitude, start_station_longitude ;'''

# %%
pd.read_csv(io(queryCartoDB(group1)), sep=',')
# Out:
#      start_station_latitude  start_station_longitude
# 0                 40.686919               -73.976682
# 1                 40.753202               -73.977987
# 2                 40.715422               -74.011220
# 3                 40.745497               -74.001971
# 4                 40.744751               -73.999154
# 5                 40.742065               -74.004432
# 6                 40.740964               -73.986022
# 7                 40.763406               -73.977225
# 8                 40.716059               -73.991908
# 9                 40.714948               -74.002345
# 10                40.703799               -74.008387
# 11                40.708531               -73.964090
# 12                40.727434               -73.993790
# 13                40.762288               -73.983362
# 14                40.727103               -74.002971
# 15                40.760660               -73.980420
# 16                40.685396               -73.974315
# ...

# %%
'''• Showing the number of trips started per station '''
#https://www.essentialsql.com/get-ready-to-learn-sql-server-6-group-and-summarize-your-results/

trips1 = '''SELECT start_station_id, COUNT(start_station_id)
FROM     citibike
GROUP BY start_station_id
'''

# %%
pd.read_csv(io(queryCartoDB(trips1)), sep=',')
# Out:
#      start_station_id  count
# 0                 195    137
# 1                 251    194
# 2                 285    373
# 3                 120     17
# 4                 483    229
# 5                 264    115
# 6                 497    455
# 7                 305    213
# 8                 318    486
# 9                 312    207
# 10                496    250
# 11                455    110
# 12                470    173
# 13                276     65
# 14               2008     86
# 15                313     50
# 16                262     37
# 17                362     98
# 18                151    288
# 19                384     55
# 20                119     19
# 21                399     32
# 22                356     98
# 23                270     92
# 24                437     18
# 25                514     91
# 26                518    282
# 27                329    145
# 28                268    124
# 29                531    212
# ..                ...    ...
# ...

# %%
''' but only for stations within 500m of Time Square!
- The coordinates of Time Square is (40.7577,-73.9857)'''


trips2 = '''select CDB_TransformToWebmercator(CDB_LatLng(start_station_latitude, start_station_longitude))
as the_geom_webmercator, min(cartodb_id) as cartodb_id
from citibike
where ST_DWithin(CDB_LatLng(start_station_latitude, start_station_longitude)::geography,
                 CDB_LatLng(40.7577, -73.9857)::geography,500)
group by start_station_id, start_station_latitude, start_station_longitude; '''

# %%
pd.read_csv(io(queryCartoDB(trips2)), sep=',')
# Out:
#                                 the_geom_webmercator  cartodb_id
# 0  0101000020110F0000F55695027D6B5FC186E5BB69D7FB...          33
# 1  0101000020110F00001607D538556B5FC119A6CA6F41FC...         124
# 2  0101000020110F000004AF971C1D6B5FC17A48F3C1A8FB...          54
# 3  0101000020110F00009BB87D02B76A5FC146C144E9E5FB...          19
# 4  0101000020110F0000F22A632FBE6A5FC1363A28CFADFB...        1115
# 5  0101000020110F00003F9300B2976B5FC1B8B88F3102FC...         783
# 6  0101000020110F000020D6742CE16A5FC112F4D73D73FC...          42

# %%
'''Find the station that had the longest average trip duration during
weekends and within 500m of TimeSquare! '''

all1= '''
SELECT
    start_station_id,
    CDB_TransformToWebmercator(CDB_LatLng(
        start_station_latitude,
        start_station_longitude)
) as the_geom_webmercator,
MIN(cartodb_id) as cartodb_id,
AVG(tripduration) as avg_duration

FROM citibike

WHERE

ST_DWithin(
    CDB_LatLng(
        start_station_latitude,
    start_station_longitude
)::geography,
    CDB_LatLng(40.7577,-73.9857)::geography,
    500)
AND
    extract(DOW FROM starttime) IN (0,6)

GROUP BY
    start_station_id,
    start_station_latitude,
    start_station_longitude
    
ORDER BY avg_duration DESC

LIMIT 1'''

# %%
pd.read_csv(io(queryCartoDB(all1)), sep=',')
# Out:
#    start_station_id                               the_geom_webmercator  \
# 0               173  0101000020110F000020D6742CE16A5FC112F4D73D73FC...
#
#    cartodb_id  avg_duration
# 0          42   1010.104167

# %%
'''Extra: create lines for trips started from stations within 500m of Times
Squares and lasted less than 2 hours. The number of trips per each
pair of stations are output as attributes of these lines. '''

all2= '''
SELECT
    start_station_id,
    end_station_id,
    ST_Makeline(
            CDB_TransformToWebmercator(CDB_LatLng(
                start_station_latitude,
                start_station_longitude
            )),
            CDB_TransformToWebmercator(CDB_LatLng(
                end_station_latitude,
                end_station_longitude
            ))
        ) as the_geom_webmercator,
    MIN(cartodb_id) as cartodb_id,
    AVG(tripduration) as avg_duration
FROM citibike

WHERE
    tripduration<7200
and
    ST_DWithin(
        CDB_LatLng(
            start_station_latitude,
            start_station_longitude
        )::geography,
    CDB_LatLng(40.7577,-73.9857)::geography,
    500)
GROUP BY
    start_station_id,
    start_station_latitude,
    start_station_longitude,
    end_station_id,
    end_station_latitude,
    end_station_longitude'''

# %% [markdown]
# ![bashrc aliases and functions](<iframe width="100%" height="520" frameborder="0" src="https://mariums.carto.com/builder/17f397ba-2a9d-4571-913d-405cf626957d/embed" allowfullscreen webkitallowfullscreen mozallowfullscreen oallowfullscreen msallowfullscreen></iframe>)

# %%
'''this is the carto map: https://mariums.carto.com/builder/17f397ba-2a9d-4571-913d-405cf626957d/embed'''

pd.read_csv(io(queryCartoDB(all2)), sep=',')
# Out:
#      start_station_id  end_station_id  \
# 0                 173             528
# 1                 477             435
# 2                 465             538
# 3                 493             512
# 4                 524              72
# 5                 465             446
# 6                 524             160
# 7                2021             459
# 8                 493             442
# 9                 477             263
# 10                465             332
# 11                173             493
# 12                493             454
# 13               2021             495
# 14                529             164
# 15                493             477
# 16               2021             153
# 17                465             254
# 18                529             422
# 19                477             284
# 20                477             318
# 21                524             515
# 22                493             478
# ...

# %% [markdown]
# [my_map](https://mariums.carto.com/builder/f920a775-7d49-418a-aaa5-e2591dfe70ce/embed)
